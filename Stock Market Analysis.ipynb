# %%
import pandas as pd
import datetime
import pandas_datareader as web
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import style
# %matplotlib inline

# %%
start_date1=datetime.datetime(2005,1,1)
start_date2=datetime.datetime(2005,1,1)
end_date=datetime.datetime(2020,2,10)

# %%
google=web.DataReader("GOOG",'yahoo',start_date1,end_date)
tcs=web.DataReader("TCS.NS",'yahoo',start_date2,end_date)

# %%
tcs.head()
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2005-01-03  169.587006  166.932007  166.932007  169.158005  4734168.0
# 2005-01-04  169.250000  166.645004  168.750000  167.658005  4979104.0
# 2005-01-05  167.524994  160.037994  167.524994  165.625000  9604320.0
# 2005-01-06  168.250000  161.561996  165.000000  165.057007  8006888.0
# 2005-01-07  168.125000  164.082993  166.250000  167.494995  7623136.0
#
#             Adj Close
# Date
# 2005-01-03  92.665100
# 2005-01-04  91.843376
# 2005-01-05  90.729691
# 2005-01-06  90.418564
# 2005-01-07  91.754066

# %%
goog_close=google.drop(google.columns[0:5],axis=1)
tcs_close=tcs.drop(reliance.columns[0:5],axis=1)

# %%
style.use('dark_background')
plt.figure(figsize=(10,8))
plt.subplot(2,1,1)
sns.lineplot(x=goog_close.index,y=goog_close['Adj Close'],color='red')
plt.title('GOOGLE STOCK PRICES:2005 to 2020')

plt.subplot(2,1,2)
sns.lineplot(x=tcs_close.index,y=tcs_close['Adj Close'],color='yellow')
plt.title('TCS STOCK PRICES:2000 to 2020')
plt.tight_layout();
